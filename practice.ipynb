# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
names=['omkar','devesh','dhaval']
scores=[90,87,89]

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(y=scores)  # Box plot only needs numerical values
plt.ylabel("Scores")
plt.title("Box Plot of Student Scores")
plt.show()
